# %% [markdown]
# # Find Pairs

# %%
from malariagen_data.pv4 import Pv4
import pandas as pd

# %%
pv4 = Pv4("gs://pv4_staging/")

# %%
pv4_metadata = pv4.sample_metadata()

pv4_metadata.head()
# Out:
#       Sample           Study   Site First-level administrative division  \
# 0  BBH-1-125  X0009-PV-ET-LO  Jimma                    Ethiopia: Oromia
# 1  BBH_1_132  X0009-PV-ET-LO  Jimma                    Ethiopia: Oromia
# 2  BBH_1_137  X0009-PV-ET-LO  Jimma                    Ethiopia: Oromia
# 3  BBH_1_153  X0009-PV-ET-LO  Jimma                    Ethiopia: Oromia
# 4  BBH_1_162  X0009-PV-ET-LO  Jimma                    Ethiopia: Oromia
#
#     Country       Lat       Long  Year         ENA  \
# 0  Ethiopia  7.683331  36.851318  2016  ERR2678989
# 1  Ethiopia  7.683331  36.851318  2016  ERR2678991
# 2  Ethiopia  7.683331  36.851318  2016  ERR2679003
# 3  Ethiopia  7.683331  36.851318  2016  ERR2678992
# 4  Ethiopia  7.683331  36.851318  2016  ERR2678993
#
#   All samples same individual Population  % callable  QC pass  \
# 0                   BBH-1-125         AF       88.52     True
# 1                   BBH_1_132         AF       90.20     True
# ...

# %%
pv4_metadata_pairs = pv4_metadata.loc[(pv4_metadata['All samples same individual'].str.contains(","))]
pv4_metadata_pairs
# Out:
#                       Sample                      Study       Site  \
# 31    Colombia_30102100438-A  X0001-PV-MULTI-HUPALO2016  Tierralta
# 32    Colombia_30102100438-B  X0001-PV-MULTI-HUPALO2016  Tierralta
# 35    Colombia_30102100441-A  X0001-PV-MULTI-HUPALO2016  Tierralta
# 36    Colombia_30102100441-B  X0001-PV-MULTI-HUPALO2016  Tierralta
# 37    Colombia_30102100443-A  X0001-PV-MULTI-HUPALO2016  Tierralta
# ...                      ...                        ...        ...
# 1874                VVX12145        1157-PV-MULTI-PRICE   Krong Pa
# 1875                VVX12150        1157-PV-MULTI-PRICE   Krong Pa
# 1876                VVX12151        1157-PV-MULTI-PRICE   Krong Pa
# 1883       india_C0924_Day_0  X0001-PV-MULTI-HUPALO2016    Chennai
# 1884       india_C0924_Day_2  X0001-PV-MULTI-HUPALO2016    Chennai
#
#      First-level administrative division   Country        Lat        Long  \
# 31                     Colombia: Cordoba  Colombia   8.172778  -76.059444
# ...

# %%
pv4_metadata_pairs = pv4_metadata_pairs.sort_values('Sample')

# %%
pv4_metadata_pairs['All samples same individual'].unique()
# Out:
# array(['Colombia_30102100438-A,Colombia_30102100438-B',
#        'Colombia_30102100441-A,Colombia_30102100441-B',
#        'Colombia_30102100443-A,Colombia_30102100443-B',
#        'PD0607-C,PD0623-C', 'PD0620-C,PD0677-C', 'PD0622-C,PD0622-Cx',
#        'PH0073-CW,PH0100-C', 'PH0188-C,PH0311-CW,PH0317-C',
#        'PH0189-C,PH0312-C,PH0318-C', 'PH0190-C,PH0313-C,PH0319-C',
#        'PH0309-C,PH0315-C', 'PH0310-C,PH0316-C',
#        'PJ0004-C,PJ0005-C,PJ0009-C', 'PJ0006-C,PJ0006-CW',
#        'PJ0007-C,PJ0010-C', 'PJ0008-C,PJ0165-C', 'PJ0012-CW,PJ0012-Cx',
#        'PJ0034-CWx,PJ0035-C', 'PJ0043-C,PJ0311-C', 'PJ0044-CW,PJ0273-C',
#        'PJ0046-C,PJ0274-C', 'PJ0046-Cx,PJ0047-C,PJ0275-C',
#        'PJ0052-CW,PJ0277-C', 'PJ0054-CW,PJ0279-C',
#        'PJ0054-Cx,PJ0055-C,PJ0280-C', 'PJ0057-C,PJ0313-C',
#        'PJ0058-CW,PJ0281-C', 'PJ0059-C,PJ0282-C', 'PJ0063-C,PJ0283-C',
#        'PJ0065-C,PJ0285-C', 'PJ0067-CWx,PJ0068-C',
#        'PJ0069-Cx,PJ0070-CW,PJ0132-Cx,PJ0286-C',
# ...
